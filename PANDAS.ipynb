# %%
import pandas as pd

# %%
users=pd.read_csv("u.user",sep='|')

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# 5          6   42      M      executive    98101
# 6          7   57      M  administrator    91344
# 7          8   36      M  administrator    05201
# 8          9   29      M        student    01002
# 9         10   53      M         lawyer    90703
# 10        11   39      F          other    30329
# 11        12   28      F          other    06405
# 12        13   47      M       educator    29206
# 13        14   45      M      scientist    55106
# 14        15   49      F       educator    97301
# 15        16   21      M  entertainment    10309
# 16        17   30      M     programmer    06355
# 17        18   35      F          other    37212
# ...

# %%
users.shape
# Out:
# (943, 5)

# %%
users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
users.mean()
# Out:
# user_id    472.000000
# age         34.051962
# dtype: float64

# %%
users['gender'].value_counts()
# Out:
# M    670
# F    273
# Name: gender, dtype: int64

# %%
drinks=pd.read_csv("drinks.csv")

# %%
drinks
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
drinks['beer_servings'].mean()
# Out:
# 106.16062176165804

# %% [markdown]
# Three most frequent occupations

# %%
users['occupation'].value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# salesman          12
# lawyer            12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %%
users.sort_values(by=['age','gender'],ascending='False')
# Out:
#      user_id  age gender     occupation zip_code
# 29        30    7      M        student    55436
# 470      471   10      M        student    77459
# 288      289   11      M           none    94619
# 608      609   13      F        student    55106
# 673      674   13      F        student    55337
# 141      142   13      M          other    48118
# 627      628   13      M           none    94306
# 879      880   13      M        student    83702
# 205      206   14      F        student    53115
# 812      813   14      F        student    02136
# 886      887   14      F        student    27249
# 280      281   15      F        student    06059
# 617      618   15      F        student    44212
# 848      849   15      F        student    25652
# 100      101   15      M        student    05146
# 178      179   15      M  entertainment    20755
# 460      461   15      M        student    98102
# 433      434   16      F        student    49705
# ...

# %% [markdown]
# only show users with age less than 20

# %%
df=users.age<20

# %%
age=users[users.age<20]

# %%
age
# Out:
#      user_id  age gender     occupation zip_code
# 29        30    7      M        student    55436
# 35        36   19      F        student    93117
# 51        52   18      F        student    55105
# 56        57   16      M           none    84010
# 66        67   17      M        student    60402
# 67        68   19      M        student    22904
# 100      101   15      M        student    05146
# 109      110   19      M        student    77840
# 141      142   13      M          other    48118
# 178      179   15      M  entertainment    20755
# 205      206   14      F        student    53115
# 220      221   19      M        student    20685
# 222      223   19      F        student    47906
# 245      246   19      M        student    28734
# 256      257   17      M        student    77005
# 257      258   19      F        student    77801
# 261      262   19      F        student    78264
# 269      270   18      F        student    63119
# ...

# %%
users[users['age']<20&users['gender']=='M']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in rand_(left, right)
#     186 def rand_(left, right):
# --> 187     return operator.and_(right, left)
#     188
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1803                 try:
# -> 1804                     result = libops.scalar_binop(x, y, op)
#    1805                 except (TypeError, ValueError, AttributeError,
#
# ...

# %% [markdown]
# most frequent occupation for age > 60
# filter drinks to include europian countries
# calculate the mean beer servings

# %%
df=drinks.query("continent=='EU'")

# %%
df['beer_servings'].mean()
# Out:
# 193.77777777777777

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-53c3146bdb00> in <module>
# ----> 1 agee=users.query["age>60"]
#
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# determine which countries have the highest total_litres_of_pure_alcohol

# %%
drinks.sort_values(by=['total_litres_of_pure_alcohol'],ascending='True')
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 0           Afghanistan              0                0              0
# 147          San Marino              0                0              0
# 128            Pakistan              0                0              0
# 46          North Korea              0                0              0
# 13           Bangladesh              0                0              0
# 111              Monaco              0                0              0
# 106    Marshall Islands              0                0              0
# 103            Maldives              0                0              0
# 107          Mauritania              0                0              0
# 90               Kuwait              0                0              0
# 79                 Iran              0                0              0
# 97                Libya              0                0              0
# ...

# %%
drinks.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
drinks['ml']=drinks.total_litres_of_pure_alcohol*1000

# %%
drinks
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
drinks.drop('ml',axis=1,inplace=True)

# %%
drinks[drinks.continent.isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
drinks.isnull().sum(axis=0)
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
dr=drinks.notnull()

# %%
drinks.continent.value_counts(dropna=False)
# Out:
# AF     53
# EU     45
# AS     44
# NaN    23
# OC     16
# SA     12
# Name: continent, dtype: int64

# %%
drinks.dropna().shape
# Out:
# (170, 6)

# %%
ufodf=pd.read_csv("ufo.csv")

# %%
ufodf.shape
# Out:
# (80543, 5)

# %%
ufodf
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %% [markdown]
# What are the 4 most frequenr colours reported?

# %%
ufodf['Colors Reported'].value_counts()
# Out:
# ORANGE                          5216
# RED                             4809
# GREEN                           1897
# BLUE                            1855
# YELLOW                           842
# RED ORANGE                       486
# RED GREEN                        469
# RED BLUE                         445
# RED GREEN BLUE                   166
# GREEN BLUE                       147
# RED YELLOW                       146
# ORANGE YELLOW                    137
# ORANGE GREEN                      66
# ORANGE BLUE                       58
# YELLOW GREEN                      53
# RED YELLOW BLUE                   36
# RED YELLOW GREEN                  35
# RED ORANGE YELLOW                 32
# YELLOW BLUE                       27
# RED YELLOW GREEN BLUE             26
# RED ORANGE BLUE                   21
# YELLOW GREEN BLUE                 13
# ORANGE GREEN BLUE                 13
# RED ORANGE GREEN                  12
# RED ORANGE GREEN BLUE              8
# ...

# %% [markdown]
# For reports in VA what is the most frequent city?

# %%
df=ufodf.query("State=='VA'")

# %%
df['City'].value_counts()
# Out:
# Virginia Beach               110
# Richmond                      92
# Alexandria                    48
# Roanoke                       35
# Chesapeake                    33
# Fredericksburg                31
# Norfolk                       31
# Arlington                     30
# Woodbridge                    27
# Hampton                       26
# Manassas                      23
# Charlottesville               22
# Fairfax                       22
# Newport News                  22
# Lynchburg                     21
# Winchester                    19
# Williamsburg                  18
# Portsmouth                    17
# Stafford                      17
# Danville                      17
# Vienna                        16
# Midlothian                    15
# Leesburg                      15
# Harrisonburg                  14
# Falls Church                  14
# Front Royal                   13
# Sterling                      13
# Ashburn                       12
# ...

# %%
df.iloc[10:20]
# Out:
#                City Colors Reported Shape Reported State             Time
# 382         Norfolk             NaN          CIGAR    VA    9/9/1956 5:55
# 580         Bristol             NaN           DISK    VA  1/15/1960 22:00
# 756        Hopewell             NaN          LIGHT    VA   9/1/1962 15:00
# 762         Ft. Lee             NaN            NaN    VA  10/15/1962 0:00
# 780      Alexandria             RED          LIGHT    VA  4/20/1963 17:00
# 832  Virginia Beach             NaN         CIRCLE    VA  7/15/1963 21:00
# 849   Prince George             NaN           DISK    VA  10/4/1963 19:10
# 858           Fries             NaN       CYLINDER    VA  3/30/1964 13:00
# 894      Alexandria             RED           DISK    VA  6/28/1964 21:00
# 912    Fishersville             NaN       FIREBALL    VA  7/15/1964 19:00

# %%
users['ismale']=users.gender.map({'F':0,'M':1})

# %%
users
# Out:
#      user_id  age gender     occupation zip_code  ismale
# 0          1   24      M     technician    85711       1
# 1          2   53      F          other    94043       0
# 2          3   23      M         writer    32067       1
# 3          4   24      M     technician    43537       1
# 4          5   33      F          other    15213       0
# 5          6   42      M      executive    98101       1
# 6          7   57      M  administrator    91344       1
# 7          8   36      M  administrator    05201       1
# 8          9   29      M        student    01002       1
# 9         10   53      M         lawyer    90703       1
# 10        11   39      F          other    30329       0
# 11        12   28      F          other    06405       0
# 12        13   47      M       educator    29206       1
# 13        14   45      M      scientist    55106       1
# 14        15   49      F       educator    97301       0
# ...
